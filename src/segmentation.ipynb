# %%
import os
import torch
import torchvision
from d2l import torch as d2l
# %matplotlib inline
import matplotlib.pyplot as plt
from models.utils import *
import torch
import torch.nn as nn
import torch.nn.functional as F
import models

# %%
import torch
from torch.utils.data import Dataset
import torchvision.transforms.v2 as transforms
from sklearn.model_selection import train_test_split
import numpy as np

class VOCSegmentation(Dataset):
    def __init__(self, images_path = '/mnt/beegfs/ksanka/semiFL/images.npy', masks_path = '/mnt/beegfs/ksanka/semiFL/masks.npy',split = 'train'):
        self.split = split
        self.train_indices, self.test_indices = train_test_split(range(2913), test_size=0.3, random_state=42)

        if split == 'train':
            # self.transform =  transforms.Compose([
            #                     #transforms.ColorJitter(contrast=0.5),
            #                     transforms.RandomHorizontalFlip(0.5),
            #                     transforms.RandomRotation(30),
            #                     #transforms.ToTensor()
            #                     #transforms.CenterCrop(480),
            #                 ])
            self.transform = None
            self.ind = np.array(self.train_indices)

        else:
            self.transform = None#transforms.ToTensor()
            self.ind = np.array(self.test_indices)
        self.images_path = images_path
        self.data = np.load(images_path, mmap_mode='r')#[self.ind,:]
        self.target = np.load(masks_path, mmap_mode='r')#[self.ind,:]
        self.id = np.arange(len(self.target))#[self.ind,:]
        self.other = {'id': self.id}
        self.target_size = self.target[0].shape

    def __len__(self):        
        return len(self.ind)
        # if self.split == 'train':
        #     return len(self.train_indices)
        # elif self.split == "test":
        #     return len(self.test_indices)
        # else:
        #     raise ValueError("split must be either train or test")
    
        #return len(self.images)  # Assuming images and masks have the same length
    
    def __repr__(self):
        fmt_str = 'Dataset {}\nSize: {}\nRoot: {}\nSplit: {}\nTransforms: {}'.format(
            self.__class__.__name__, self.__len__(), self.images_path, self.split,self.transform.__repr__())
        return fmt_str

    def __getitem__(self, idx):
        idx = self.ind[idx]
        image = self.data[idx]
        #print(idx)
        mask = self.target[idx]
        other = {'id' : self.id[idx]}
        #id = self.id[idx]

        # Apply transformations if provided
        inp = {**other, 'data':torch.tensor(image), 'target' : torch.tensor(mask)}
        if self.transform:
            inp = self.transform(inp)
            #image = self.transform(image)
            #image,mask = self.transform(image,mask)
            #mask = self.transform(mask)
        return inp



class SimpleDataset(Dataset):
    def __init__(self):
        #self.num_samples = num_samples
        self.data = torch.rand(100,3,128,128)
        self.target = torch.rand(100,1,128,128)
        self.transform = None
        self.ind = np.arange(100)


    def __len__(self):
        return len(self.ind)
        #return self.num_samples

    def __getitem__(self, idx):
        didx = self.ind[idx]
        data = torch.tensor(self.data[didx,:])
        tgt = self.target[idx]
        inp = {'data': data , 'target':tgt}
        #print(data.shape,tgt.shape)
        if self.transform:
            inp = self.transform(inp)
            #return {'data':self.transform(torch.tensor(self.data[didx,:])), 'target':self.target[idx]} # 'target':self.transform(self.target[idx])
        return inp

device = 'cuda'

ds_train = VOCSegmentation(split = 'train')
ds_test = VOCSegmentation(split = 'test')

trainloader = torch.utils.data.DataLoader(ds_train, batch_size=12, shuffle=True)
testloader = torch.utils.data.DataLoader(ds_test, batch_size=12, shuffle=True)

# %%
from torchmetrics.classification import Dice

dice1 = Dice(average='macro',num_classes = 21,ignore_index = 0).to('cuda')
dice2 = Dice(average='macro',num_classes = 21).to('cuda')
def compute_iou(pred_mask,true_mask):
    '''
    Compute dice score by ignoring background
    '''
    
    #print(pred_mask.shape,true_mask.shape)
    pred_mask = torch.argmax(pred_mask,1)
    return dice1(pred_mask.to('cuda'), true_mask.to('cuda')).item()
    # intersection = np.logical_and(true_mask, pred_mask)
    # union = np.logical_or(true_mask, pred_mask)
    # iou_score = np.sum(intersection) / np.sum(union)
    # return iou_score

def compute_dice_coefficient(pred_mask,true_mask):
    pred_mask = torch.argmax(pred_mask,1)
    #dice = Dice(average='macro',num_classes = 21).to(pred_mask.device)
    return dice2(pred_mask.to('cuda'), true_mask.to('cuda')).item()


def compute_pixel_accuracy(pred_mask,true_mask):
    pred_mask = torch.argmax(pred_mask,1)
    correct_pixels = torch.sum(true_mask == pred_mask)
    total_pixels = true_mask.view(-1).size()[0]
    pixel_accuracy = correct_pixels / total_pixels
    return pixel_accuracy.item()

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'deeplabv3_resnet50', weights='DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1').to(device)
# Out:
# Using cache found in /home/ksanka/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
model.eval()
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
quantized_full_model = torch.quantization.quantize_dynamic(model, dtype=torch.qint8)

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.SGD(model.classifier.parameters(), lr=0.03)

def eval(model,test):
    metrics = {'loss':[],'pa':[],'dice':[],'iou':[]}
    model.eval()
    with torch.no_grad():
        for i,batch in enumerate(test):
            inputs,labels=  batch['data'].to(device),batch['target'].to(device)
            #input,labels = next(iter(trainloader))
            #input,labels = input.to(device),labels.to(device)
            outputs = model(inputs)['out']
            #print(outputs.keys())
            loss = criterion(outputs, labels)
            #pred = torch.max(torch.softmax(outputs,1))
            pa = compute_pixel_accuracy(outputs,labels)
            dice = compute_dice_coefficient(outputs,labels)
            iou = compute_iou(outputs,labels)
            metrics['loss'].append(loss)
            metrics['pa'].append(pa)
            metrics['dice'].append(dice)
            metrics['iou'].append(iou)
        print(f"mean loss = {torch.mean(torch.tensor(metrics['loss']))} , mean pa = {torch.mean(torch.tensor(metrics['pa']))}, mean dice = {torch.mean(torch.tensor(metrics['dice']))}")

# %%
batch = next(iter(testloader))

# %%
inp = batch['data'].to('cuda')
inp.shape
# Out:
# torch.Size([12, 3, 256, 256])

# %%
model = model.to('cuda')

# %%
eval(model,testloader)
# Out:
# mean loss = 0.27691471576690674 , mean pa = 0.9041972756385803, mean dice = 0.6236916184425354

# %%
eval(model,testloader)
# Out:
# mean loss = 0.27780094742774963 , mean pa = 0.9039435982704163, mean dice = 0.6350855231285095

# %%
eval(quantized_full_model,testloader)
# Out:
# mean loss = 0.27666449546813965 , mean pa = 0.9039584398269653, mean dice = 0.7177595496177673

# %%
op = model(batch['data'].to('cuda'))

# %%
torch.cuda.reset_peak_memory_stats()
op = model(batch['data'].to('cuda'))
max_memory_allocated = torch.cuda.max_memory_allocated() / (1024 ** 2)  # MB
max_memory_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)  # MB

# %%
print(max_memory_allocated)
# Out:
# 6727.205078125

# %%
max_memory_reserved
# Out:
# 6988.0

# %%
op = model_quantized(batch['data'].to('cuda'))

# %%
op = quantized_model_conv(batch['data'].to('cuda'))

# %%
torch.cuda.reset_peak_memory_stats()
op = model_quantized(batch['data'].to('cuda'))
max_memory_allocated = torch.cuda.max_memory_allocated() / (1024 ** 2)  # MB
max_memory_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)  # MB

# %%
max_memory_allocated, max_memory_reserved
# Out:
# (7213.92138671875, 7494.0)

# %%
quantized_model_conv = torch.quantization.quantize_dynamic(
    model, {torch.nn.Conv2d}, dtype=torch.qint8
)

# %%
import torch
import torchvision.models as models
from torch.profiler import profile, record_function, ProfilerActivity

# %%
import torch.nn as nn
from torch.quantization import QuantStub, DeQuantStub

# Define mapping for dynamic quantization of all layers
dynamic_quantization_mapping = {
    nn.Conv1d: nn.quantized.Conv1d,
    nn.Conv2d: nn.quantized.Conv2d,
    nn.Conv3d: nn.quantized.Conv3d,
    nn.ConvTranspose1d: nn.quantized.ConvTranspose1d,
    nn.ConvTranspose2d: nn.quantized.ConvTranspose2d,
    nn.ConvTranspose3d: nn.quantized.ConvTranspose3d,
    nn.Linear: nn.quantized.Linear,
    nn.ReLU: QuantStub,  # Replace with quantized version
    nn.ReLU6: QuantStub,
    nn.BatchNorm2d: nn.quantized.BatchNorm2d,
    nn.BatchNorm3d: nn.quantized.BatchNorm3d,
    # Add more layers as needed
}

# %%
model_fp32 = torch.hub.load('pytorch/vision:v0.10.0', 'deeplabv3_resnet50', weights='DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1').to(device)

model_quantized = torch.quantization.quantize_dynamic(
    model_fp32, mapping=dynamic_quantization_mapping, dtype=torch.qint8
)
# Out:
# Using cache found in /home/ksanka/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
model_quantized
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
model_quantized.state_dict()
# Out:
# OrderedDict([('backbone.conv1.weight',
#               tensor([[[[ 2.5033e-03,  1.0390e-03, -5.1337e-03,  ..., -3.5699e-02,
#                          -4.7453e-02, -6.7587e-02],
#                         [-6.3906e-03,  6.0558e-03,  3.3751e-02,  ...,  2.9455e-02,
#                          -5.6533e-03, -1.3758e-02],
#                         [-3.6212e-03, -5.5701e-04,  1.1559e-02,  ...,  1.1007e-01,
#                           9.0378e-02,  8.8566e-02],
#                         ...,
#                         [ 2.8753e-02,  3.5205e-02, -4.1636e-03,  ..., -1.2127e-01,
#                          -8.6888e-02, -4.9437e-02],
#                         [ 4.6666e-02,  8.7159e-02,  1.1415e-01,  ...,  5.0452e-02,
#                           2.9312e-03, -3.2462e-02],
#                         [-7.2365e-02, -4.5505e-02, -1.0001e-02,  ...,  5.0157e-02,
#                           4.8468e-02,  6.5176e-03]],
#
#                        [[ 2.8648e-03,  2.0979e-02,  3.7938e-02,  ...,  3.5522e-02,
#                           1.4409e-02, -2.3227e-02],
#                         [-7.4801e-03,  2.0024e-02,  7.2591e-02,  ...,  1.3909e-01,
#                           1.1146e-01,  9.3359e-02],
#                         [-5.8896e-02, -7.8241e-02, -6.8116e-02,  ...,  1.1740e-01,
#                           1.5080e-01,  1.6467e-01],
#                         ...,
#                         [ 4.7060e-02,  1.5081e-02, -7.6167e-02,  ..., -2.9687e-01,
#                          -2.4035e-01, -1.5412e-01],
#                         [ 1.1163e-01,  1.4725e-01,  1.6360e-01,  ...,  2.0222e-02,
#                       7.9598e-01, 4.7428e-01, 9.7998e+00, 1.2256e-01], device='cuda:0')),
#              ('backbone.bn1.num_batches_tracked',
#               tensor(86730, device='cuda:0')),
#              ('backbone.layer1.0.conv1.weight',
#               tensor([[[[-0.0146]],
#
#                        [[ 0.0874]],
#
#                        [[-0.0174]],
#
#                        ...,
#
#                        [[ 0.0895]],
#
#                        [[-0.2657]],
#
#                        [[-0.0782]]],
#
#
#                       [[[ 0.0135]],
#
#                        [[-0.0140]],
#
#                        [[ 0.0045]],
#
#                        ...,
#
#                        [[ 0.0381]],
#
#                        [[-0.0488]],
#
#                        [[-0.0679]]],
#
#
#                       [[[-0.0217]],
#
#                        [[ 0.0074]],
#
#                        [[-0.0115]],
#
#                        ...,
#
#                        [[ 0.0303]],
#
#                        [[ 0.0525]],
#
#                        [[-0.0140]]],
#
#
#                       ...,
#
#
#                       [[[-0.0022]],
#
#                        [[-0.0319]],
#
#                        [[ 0.0122]],
#
#                        ...,
#
#                        [[ 0.0100]],
#
#                        [[-0.0492]],
#
#                        [[ 0.0180]]],
#
#
#                       [[[-0.0384]],
#
#                        [[-0.0125]],
#
#                        [[ 0.0205]],
#
#                        ...,
#
#                        [[-0.0283]],
#
#                        [[-0.0211]],
#
#                        [[-0.0080]]],
#
#
#                       [[[-0.0286]],
#
#                        [[-0.1153]],
#
#                        [[ 0.0401]],
#
#                        ...,
#
#                        [[-0.0556]],
#
#                        [[ 0.2089]],
#
#                        [[-0.0039]]]], device='cuda:0')),
#              ('backbone.layer1.0.bn1.weight',
#               tensor([2.4486e-01, 1.0334e-01, 1.2706e-01, 1.0350e-01, 1.2884e-01, 1.0737e-02,
#                       1.2006e-01, 1.8105e-08, 1.4563e-01, 1.2789e-01, 1.7471e-01, 1.4730e-01,
#                       1.4397e-01, 8.6303e-02, 1.1616e-01, 7.4123e-02, 2.4736e-01, 9.6740e-02,
#                       1.6963e-01, 2.0354e-01, 9.3389e-02, 1.2757e-01, 1.2546e-01, 8.4640e-09,
#                       2.0485e-01, 5.5505e-03, 2.3031e-01, 4.7382e-09, 9.4989e-02, 1.3229e-01,
#                       2.5949e-02, 4.3661e-03, 8.1038e-02, 1.1933e-01, 9.9972e-02, 1.7479e-01,
#                       9.0765e-02, 1.3833e-02, 1.8253e-01, 8.6335e-02, 2.2429e-01, 1.0773e-01,
#                       9.5822e-02, 1.0458e-01, 1.9261e-01, 1.4947e-01, 1.1126e-01, 2.6390e-01,
#                       4.3570e-02, 2.2074e-02, 7.6148e-02, 2.1820e-01, 9.6359e-02, 1.0103e-01,
#                       1.7715e-01, 1.1446e-01, 1.0666e-08, 1.0709e-01, 1.1558e-08, 1.3488e-01,
#                       1.4605e-01, 1.0606e-01, 1.8495e-01, 2.6921e-01], device='cuda:0')),
#              ('backbone.layer1.0.b
-01], device='cuda:0')),
#              ('backbone.layer1.0.bn1.num_batches_tracked',
#               tensor(86730, device='cuda:0')),
#              ('backbone.layer1.0.conv2.weight',
#               tensor([[[[ 8.3959e-10, -5.6799e-10,  2.6430e-09],
#                         [ 1.9234e-09,  1.3172e-09,  3.7842e-10],
#                         [ 2.5993e-09, -1.2103e-09, -9.6159e-10]],
#
#                        [[ 4.6039e-09,  5.1432e-09,  5.4458e-09],
#                         [ 4.3093e-09,  1.9952e-09,  1.5459e-09],
#                         [ 4.2432e-09,  4.8777e-09,  2.7764e-09]],
#
#                        [[-2.7472e-09, -1.1427e-09, -6.1794e-10],
#                         [ 1.9588e-09, -1.2416e-09,  9.6001e-10],
#                         [ 2.1271e-09, -5.6724e-12, -3.0227e-09]],
#
#                        ...,
#
#                        [[-2.6019e-09, -3.0674e-09, -3.8359e-09],
#                         [-2.8127e-09, -1.6138e-09, -1.8390e-09],
#                         [-1.9807e-09, -2.1916e-10, -5.2654e-09]],
#
#                        [[-4.1976e-10, -2.7949e-09, -2.0505e-09],
#                         [-1.3769e-10, -1.7120e-09, -9.1120e-10],
#                         [-7.4532e-10, -1.9453e-09, -1.4277e-09]],
#
#                        [[ 7.5240e-10,  3.4814e-10, -2.2372e-10],
#                         [ 1.0529e-10, -2.0093e-09,  2.3419e-09],
#                         [ 9.7617e-11,  6.5590e-11,  1.3359e-09]]],
#
#
#                       [[[-1.1822e-02,  2.0816e-04,  9.2119e-03],
#                         [ 1.2648e-03, -5.2030e-04,  8.9158e-03],
#                         [ 1.0306e-02,  1.1082e-02,  1.5898e-03]],
#
#                        [[-2.2052e-03,  8.3387e-04,  4.5563e-03],
#                         [ 7.6512e-03,  7.0701e-03,  7.8738e-03],
#                         [ 1.0017e-02,  1.0474e-02, -8.4383e-04]],
#
#                        [[-6.5477e-04, -1.6681e-03,  7.5638e-03],
#                         [-3.8507e-04, -9.7152e-03, -8.0448e-05],
#                         [ 1.1506e-03, -7.3705e-03, -6.0796e-03]],
#
#                        ...,
#
#                        [[ 4.1382e-03,  4.5536e-03,  6.3923e-03],
#                         [ 7.3877e-03,  5.7986e-03,  4.5540e-03],
#                         [ 1.0831e-02,  8.8955e-03,  5.6328e-03]],
#
#                        [[ 4.5024e-04,  3.2942e-03,  5.4730e-03],
#                         [ 4.4247e-03,  4.0935e-02,  5.5847e-03],
#                         [-3.7773e-03, -8.4979e-04,  1.3224e-03]],
#
#                        [[-7.7886e-03, -2.0844e-03, -1.3515e-02],
#                         [-5.7261e-03,  5.2121e-03, -3.4849e-03],
#                         [-1.5958e-02, -1.9582e-03, -3.4406e-03]]],
#
#
#                       [[[ 3.6187e-02,  4.3262e-02,  2.8598e-02],
#                         [ 3.9609e-02,  2.7187e-02,  3.8059e-02],
#                         [ 4.3965e-02,  4.4580e-02,  3.8643e-02]],
#
#                        [[ 4.4749e-03, -7.2192e-04,  6.2258e-03],
#                         [-7.7262e-04,  3.9445e-03,  1.4000e-03],
#                         [ 2.5902e-03, -7.5680e-03, -9.1142e-04]],
#
#                        [[ 2.5182e-03, -1.0854e-02,  7.3516e-03],
#                         [-1.3816e-02, -8.9632e-03,  1.3146e-02],
#                         [-1.5886e-03, -4.1550e-03,  1.0476e-02]],
#
#                        ...,
#
#                        [[ 2.2009e-02,  1.7561e-02,  2.5311e-02],
#                         [ 2.1691e-02, -9.3965e-03,  2.1061e-02],
#                         [ 1.4271e-02,  1.2538e-02,  1.9489e-02]],
#
#                        [[ 1.1623e-02, -1.3504e-02,  1.1308e-02],
#                         [-5.8470e-03,  4.0355e-03, -1.0837e-02],
#                         [-4.2979e-03, -5.7414e-03, -4.8199e-03]],
#
#                        [[-4.9331e-03, -2.6266e-02, -1.4205e-02],
#                         [-3.6605e-02, -2.5197e-02, -3.3425e-02],
#                         [-3.8077e-02, -4.4879e-02, -3.5052e-02]]],
#
#
#                       ...,
#
#
#                       [[[ 7.3093e-10,  1.1688e-09, -2.2601e-09],
#                         [ 1.7344e-09, -7.4795e-10, -1.3268e-09],
#                         [ 9.0740e-10, -4.9377e-10,  6.6370e-11]],
#
#                        [[ 7.9720e-10, -1.0871e-09, -6.0961e-09],
#                         [ 3.6237e-09,  1.0746e-09, -9.5455e-10],
#                         [ 2.1972e-09,  1.8966e-09, -2.0753e-09]],
#
#                        [[ 1.6956e-10, -2.4971e-09, -2.8650e-09],
#                         [-1.8359e-09, -3.5820e-09, -1.6485e-09],
#                         [-6.8949e-10, -5.7391e-11, -1.9099e-09]],
#
#                        ...,
#
#                        [[-6.7396e-10,  1.5232e-09,  2.2007e-10],
#                         [-1.9728e-09, -3.8083e-09, -2.5570e-09],
#                         [ 3.3205e-09,  1.5839e-09,  1.5646e-09]],
#
#                        [[ 1.6057e-09, -5.4527e-10, -1.1003e-12],
#                         [-5.1198e-10,  1.0158e-09, -1.8821e-09],
#                         [ 2.0020e-10,  1.3272e-09, -3.4498e-09]],
#
#                        [[ 1.1166e-09,  2.8602e-10,  1.2931e-09],
#                         [ 1.3978e-09,  2.2541e-09, -1.5559e-09],
#                         [ 9.4161e-10,  2.4199e-09,  1.9550e-10]]],
#
#
#                       [[[ 5.9496e-02,  4.7259e-02,  2.5392e-02],
#                         [ 2.8663e-02,  5.5262e-04, -1.3109e-02],
#                         [ 7.6973e-03, -2.1052e-02, -3.2318e-02]],
#
#                        [[-8.6230e-04,  2.4967e-03,  1.5211e-03],
#                         [ 6.3448e-03,  6.8139e-03, -4.8454e-03],
#                         [-3.7341e-03, -1.2783e-02, -1.7298e-02]],
#
#                        [[ 5.6015e-03, -8.6265e-03, -8.9844e-03],
#                         [ 3.5344e-03, -5.0009e-03,  5.6276e-03],
#                         [ 3.4810e-03, -5.0340e-03,  7.7146e-03]],
#
#                        ...,
#
#                        [[-7.6678e-04, -2.1851e-03, -6.4031e-03],
#                         [-1.5566e-03, -7.4367e-03, -8.7040e-03],
#                        6.8468e-03,  2.7458e-02,  3.1333e-02,  4.5254e-02,  2.9083e-03,
#                        2.7830e-03,  3.4113e-02,  6.1990e-03,  7.7184e-03,  4.0673e-02,
#                        2.8940e-02,  6.0079e-02,  1.9927e-02,  3.5811e-03,  1.1367e-02,
#                        4.5369e-03,  1.8651e-03,  2.7616e-03,  1.6243e-02,  1.6874e-03,
#                        2.3598e-02,  1.2379e-02,  9.1358e-03,  2.3287e-03,  4.1031e-03,
#                        8.3961e-03,  2.5683e-03,  2.6615e-03,  5.0675e-03,  1.5513e-05,
#                        4.2085e-03, -1.4133e-12,  5.1051e-03,  4.4876e-02], device='cuda:0')),
#              ('backbone.layer1.0.bn2.num_batches_tracked',
#               tensor(86730, device='cuda:0')),
#              ('backbone.layer1.0.conv3.weight',
#               tensor([[[[-1.6102e-09]],
#
#                        [[ 7.1750e-03]],
#
#                        [[ 5.1176e-02]],
#
#                        ...,
#
#                        [[ 4.3401e-09]],
#
#                        [[-7.7599e-03]],
#
#                        [[-1.5468e-02]]],
#
#
#                       [[[ 2.3044e-09]],
#
#                        [[ 2.4050e-03]],
#
#                        [[ 5.9417e-04]],
#
#                        ...,
#
#                        [[ 9.3441e-10]],
#
#                        [[-4.2201e-04]],
#
#                        [[ 1.5632e-03]]],
#
#
#                       [[[-8.9684e-10]],
#
#                        [[-3.4398e-03]],
#
#                        [[-7.5783e-03]],
#
#                        ...,
#
#                        [[-1.3170e-09]],
#
#                        [[ 7.9981e-04]],
#
#                        [[-3.0325e-03]]],
#
#
#                       ...,
#
#
#                       [[[ 2.4609e-09]],
#
#                        [[ 2.0393e-05]],
#
#                        [[ 3.4254e-03]],
#
#                        ...,
#
#                        [[-5.0528e-09]],
#
#                        [[ 8.7991e-04]],
#
#                        [[ 3.7387e-03]]],
#
#
#                       [[[-3.0097e-09]],
#
#                        [[-7.3225e-03]],
#
#                        [[ 7.0346e-02]],
#
#                        ...,
#
#                        [[ 1.4598e-09]],
#
#                        [[-2.8661e-02]],
#
#                        [[-2.1939e-02]]],
#
#
#                       [[[ 5.7478e-10]],
#
#                        [[-6.2223e-03]],
#
#                        [[-2.7565e-02]],
#
#                        ...,
#
#                        [[ 2.4819e-09]],
#
#                        [[ 2.4177e-02]],
#
#                        [[-7.8007e-02]]]], device='cuda:0')),
#              ('backbone.layer1.0.bn3.weight',
#               tensor([ 9.4172e-02,  6.7612e-04,  1.7234e-02,  3.4999e-01,  4.7244e-02,
#                        5.8956e-02,  5.3969e-02,  2.0656e-01,  9.0102e-02,  1.6457e-01,
#                        2.1674e-01,  1.5792e-01,  1.3527e-01,  1.7555e-01,  2.1068e-01,
#                        1.5450e-01,  2.1953e-01,  1.8314e-01,  3.9781e-02,  1.2847e-01,
#                        9.8426e-02,  1.0626e-01,  4.4462e-07,  3.8185e-09,  1.7025e-01,
#                        1.9813e-04,  1.5917e-03,  1.7536e-01,  1.1015e-01,  1.5259e-01,
#                        1.0406e-01,  1.3651e-01,  1.8830e-01,  1.4607e-01,  1.3664e-01,
#                        1.4481e-01,  1.5889e-01,  2.1210e-01, -1.3248e-02,  4.2296e-02,
#                       0.0175, 0.0041, 0.0101, 0.0101, 0.0037, 0.0061, 0.0141, 0.0109, 0.0058,
#                       0.0233, 0.0137, 0.0165, 0.0067, 0.0080, 0.0143, 0.0104, 0.0060, 0.0066,
#                       0.0098, 0.0137, 0.0123, 0.0127, 0.0068, 0.0117, 0.0134, 0.0079, 0.0159,
#                       0.0071, 0.0073, 0.0104, 0.0079, 0.0053, 0.0108, 0.0111, 0.0082, 0.0089,
#                       0.0072, 0.0049, 0.0147, 0.0081, 0.0196, 0.0129, 0.0095, 0.0127, 0.0093,
#                       0.0052, 0.0119, 0.0173, 0.0084, 0.0095, 0.0113, 0.0039, 0.0051, 0.0118,
#                       0.0133, 0.0047, 0.0102, 0.0067, 0.0187, 0.0096, 0.0066, 0.0081, 0.0155,
#                       0.0065, 0.0119, 0.0086, 0.0087, 0.0135, 0.0086, 0.0069, 0.0146, 0.0105,
#                       0.0065, 0.0097, 0.0097, 0.0098, 0.0095, 0.0088, 0.0065, 0.0112, 0.0063,
#                       0.0076, 0.0130, 0.0112, 0.0114, 0.0072, 0.0090, 0.0152, 0.0086, 0.0079,
#                       0.0099, 0.0087, 0.0115, 0.0082, 0.0067, 0.0067, 0.0106, 0.0049, 0.0095,
#                       0.0113, 0.0159, 0.0104, 0.0137, 0.0084, 0.0090, 0.0128, 0.0026, 0.0182,
#                       0.0069, 0.0050, 0.0087, 0.0072, 0.0090, 0.0048, 0.0103, 0.0185, 0.0130,
#                       0.0081, 0.0103, 0.0093, 0.0091, 0.0064, 0.0120, 0.0108, 0.0086, 0.0084,
#                       0.0077, 0.0076, 0.0089, 0.0137, 0.0135, 0.0143, 0.0088, 0.0118, 0.0107,
#                       0.0068, 0.0117, 0.0083, 0.0118], device='cuda:0')),
#              ('aux_classifier.1.num_batches_tracked',
#               tensor(86730, device='cuda:0')),
#              ('aux_classifier.4.weight',
#               tensor([[[[ 0.1393]],
#
#                        [[ 0.0192]],
#
#                        [[-0.2024]],
#
#                        ...,
#
#                        [[ 0.0957]],
#
#                        [[ 0.1031]],
#
#                        [[ 0.1969]]],
#
#
#                       [[[-0.1030]],
#
#                        [[-0.0716]],
#
#                        [[ 0.0460]],
#
#                        ...,
#
#                        [[-0.0458]],
#
#                        [[-0.1292]],
#
#                        [[-0.0203]]],
#
#
#                       [[[-0.0885]],
#
#                        [[-0.0294]],
#
#                        [[-0.0144]],
#
#                        ...,
#
#                        [[-0.0766]],
#
#                        [[ 0.0593]],
#
#                        [[-0.0180]]],
#
#
#                       ...,
#
#
#                       [[[ 0.2164]],
#
#                        [[-0.0895]],
#
#                        [[-0.0197]],
#
#                        ...,
#
#                        [[ 0.1905]],
#
#                        [[ 0.1309]],
#
#                        [[-0.0425]]],
#
#
#                       [[[-0.0502]],
#
#                        [[ 0.1271]],
#
#                        [[ 0.0427]],
#
#                        ...,
#
#                        [[-0.1256]],
#
#                        [[ 0.2076]],
#
#                        [[ 0.0132]]],
#
#
#                       [[[ 0.2056]],
#
#                        [[-0.0335]],
#
#                        [[-0.0340]],
#
#                        ...,
#
#                        [[-0.1688]],
#
#                        [[-0.0357]],
#
#                        [[ 0.1954]]]], device='cuda:0')),
#              ('aux_classifier.4.bias',
#               tensor([ 0.8720, -0.1463, -0.1448, -0.0780, -0.1318, -0.1184, -0.1139,  0.0500,
#                       -0.0599, -0.0853, -0.0777,  0.2649,  0.0165, -0.0843, -0.0376,  0.3010,
#                       -0.0715, -0.1799, -0.0596, -0.0140, -0.1012], device='cuda:0'))])

# %%
import torch
import torch.quantization

# Load the pre-trained model
model  = torch.hub.load('pytorch/vision:v0.10.0', 'deeplabv3_resnet50', weights='DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1').to(device).eval()

modules_to_fuse = [
    ['conv1', 'bn1', ],
    ['conv2', 'bn2', ],
    # Add more module patterns to fuse
]

# torch.quantization.fuse_modules(model.backbone, modules_to_fuse,inplace=True)
# torch.quantization.fuse_modules(model.classifier, modules_to_fuse,inplace=True)



# Set the quantization configuration
qconfig = torch.quantization.get_default_qconfig('qnnpack')
#qnnpack, fbgemm
# Prepare the model for static quantization
model.qconfig = qconfig
torch.quantization.prepare(model, inplace=True)


# Calibrate the quantization parameters on a representative dataset
calibration_loader = trainloader

for batch in calibration_loader:
    inputs, labels = batch['data'].to(device),batch['target'].to(device)
    model(inputs)

# # Convert the model to quantized form
torch.quantization.convert(model, inplace=True)

# # Optionally, offload the quantized model to CPU for inference
# model = model.to('cpu')

# # Evaluate the quantized model
# eval_loader = your_evaluation_dataloader
# accuracy = 0.0
# for batch in eval_loader:
#     inputs, labels = batch
#     outputs = model(inputs)
#     accuracy += compute_accuracy(outputs, labels)

# print(f'Quantized model accuracy: {accuracy / len(eval_loader)}')
# Out:
# Using cache found in /home/ksanka/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
def get_fusible_module_patterns(model):
    fusible_patterns = []
    for name, module in model.named_modules():
        if isinstance(module, (torch.nn.Conv2d, torch.nn.Linear)):
            conv_bn_relu = []
            parent_name = name
            for child_name, child_module in module.named_children():
                full_child_name = parent_name + '.' + child_name if parent_name else child_name
                if isinstance(child_module, torch.nn.BatchNorm2d):
                    conv_bn_relu.append(full_child_name)
                elif isinstance(child_module, torch.nn.ReLU):
                    conv_bn_relu.append(full_child_name)
                    fusible_patterns.append(conv_bn_relu)
                    break
    return fusible_patterns

# %%
model.classifier
# Out:
# DeepLabHead(
#   (0): ASPP(
#     (convs): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (1): ASPPConv(
#         (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (2): ASPPConv(
#         (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (3): ASPPConv(
#         (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (4): ASPPPooling(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#       )
#     )
#     (project): Sequential(
#       (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): ReLU()
#   (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
model_params = list(model.named_parameters())

# Print names and parameters
for name, param in model_params:
    print(f"Name: {name}, Shape: {param.shape}")
# Out:
# Name: backbone.conv1.weight, Shape: torch.Size([64, 3, 7, 7])
# Name: backbone.conv1.bias, Shape: torch.Size([64])
# Name: backbone.layer1.0.conv1.weight, Shape: torch.Size([64, 64, 1, 1])
# Name: backbone.layer1.0.bn1.weight, Shape: torch.Size([64])
# Name: backbone.layer1.0.bn1.bias, Shape: torch.Size([64])
# Name: backbone.layer1.0.conv2.weight, Shape: torch.Size([64, 64, 3, 3])
# Name: backbone.layer1.0.bn2.weight, Shape: torch.Size([64])
# Name: backbone.layer1.0.bn2.bias, Shape: torch.Size([64])
# Name: backbone.layer1.0.conv3.weight, Shape: torch.Size([256, 64, 1, 1])
# Name: backbone.layer1.0.bn3.weight, Shape: torch.Size([256])
# Name: backbone.layer1.0.bn3.bias, Shape: torch.Size([256])
# Name: backbone.layer1.0.downsample.0.weight, Shape: torch.Size([256, 64, 1, 1])
# Name: backbone.layer1.0.downsample.1.weight, Shape: torch.Size([256])
# Name: backbone.layer1.0.downsample.1.bias, Shape: torch.Size([256])
# Name: backbone.layer1.1.conv1.weight, Shape: torch.Size([64, 256, 1, 1])
# Name: backbone.layer1.1.bn1.weight, Shape: torch.Size([64])
# Name: backbone.layer1.1.bn1.bias, Shape: torch.Size([64])
# Name: backbone.layer1.1.conv2.weight, Shape: torch.Size([64, 64, 3, 3])
# Name: backbone.layer1.1.bn2.weight, Shape: torch.Size([64])
# Name: backbone.layer1.1.bn2.bias, Shape: torch.Size([64])
# Name: backbone.layer1.1.conv3.weight, Shape: torch.Size([256, 64, 1, 1])
# Name: backbone.layer1.1.bn3.weight, Shape: torch.Size([256])
# Name: backbone.layer1.1.bn3.bias, Shape: torch.Size([256])
# Name: backbone.layer1.2.conv1.weight, Shape: torch.Size([64, 256, 1, 1])
# Name: backbone.layer1.2.bn1.weight, Shape: torch.Size([64])
# Name: backbone.layer1.2.bn1.bias, Shape: torch.Size([64])
# Name: backbone.layer1.2.conv2.weight, Shape: torch.Size([64, 64, 3, 3])
# Name: backbone.layer1.2.bn2.weight, Shape: torch.Size([64])
# Name: backbone.layer1.2.bn2.bias, Shape: torch.Size([64])
# Name: backbone.layer1.2.conv3.weight, Shape: torch.Size([256, 64, 1, 1])
# Name: backbone.layer1.2.bn3.weight, Shape: torch.Size([256])
# Name: backbone.layer1.2.bn3.bias, Shape: torch.Size([256])
# Name: backbone.layer2.0.conv1.weight, Shape: torch.Size([128, 256, 1, 1])
# Name: backbone.layer2.0.bn1.weight, Shape: torch.Size([128])
# Name: backbone.layer2.0.bn1.bias, Shape: torch.Size([128])
# Name: backbone.layer2.0.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Name: backbone.layer2.0.bn2.weight, Shape: torch.Size([128])
# Name: backbone.layer2.0.bn2.bias, Shape: torch.Size([128])
# Name: backbone.layer2.0.conv3.weight, Shape: torch.Size([512, 128, 1, 1])
# Name: backbone.layer2.0.bn3.weight, Shape: torch.Size([512])
# Name: backbone.layer2.0.bn3.bias, Shape: torch.Size([512])
# Name: backbone.layer2.0.downsample.0.weight, Shape: torch.Size([512, 256, 1, 1])
# Name: backbone.layer2.0.downsample.1.weight, Shape: torch.Size([512])
# Name: backbone.layer2.0.downsample.1.bias, Shape: torch.Size([512])
# Name: backbone.layer2.1.conv1.weight, Shape: torch.Size([128, 512, 1, 1])
# Name: backbone.layer2.1.bn1.weight, Shape: torch.Size([128])
# Name: backbone.layer2.1.bn1.bias, Shape: torch.Size([128])
# Name: backbone.layer2.1.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Name: backbone.layer2.1.bn2.weight, Shape: torch.Size([128])
# Name: backbone.layer2.1.bn2.bias, Shape: torch.Size([128])
# Name: backbone.layer2.1.conv3.weight, Shape: torch.Size([512, 128, 1, 1])
# Name: backbone.layer2.1.bn3.weight, Shape: torch.Size([512])
# Name: backbone.layer2.1.bn3.bias, Shape: torch.Size([512])
# Name: backbone.layer2.2.conv1.weight, Shape: torch.Size([128, 512, 1, 1])
# Name: backbone.layer2.2.bn1.weight, Shape: torch.Size([128])
# Name: backbone.layer2.2.bn1.bias, Shape: torch.Size([128])
# Name: backbone.layer2.2.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Name: backbone.layer2.2.bn2.weight, Shape: torch.Size([128])
# Name: backbone.layer2.2.bn2.bias, Shape: torch.Size([128])
# Name: backbone.layer2.2.conv3.weight, Shape: torch.Size([512, 128, 1, 1])
# Name: backbone.layer2.2.bn3.weight, Shape: torch.Size([512])
# Name: backbone.layer2.2.bn3.bias, Shape: torch.Size([512])
# Name: backbone.layer2.3.conv1.weight, Shape: torch.Size([128, 512, 1, 1])
# Name: backbone.layer2.3.bn1.weight, Shape: torch.Size([128])
# Name: backbone.layer2.3.bn1.bias, Shape: torch.Size([128])
# Name: backbone.layer2.3.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Name: backbone.layer2.3.bn2.weight, Shape: torch.Size([128])
# Name: backbone.layer2.3.bn2.bias, Shape: torch.Size([128])
# Name: backbone.layer2.3.conv3.weight, Shape: torch.Size([512, 128, 1, 1])
# Name: backbone.layer2.3.bn3.weight, Shape: torch.Size([512])
# Name: backbone.layer2.3.bn3.bias, Shape: torch.Size([512])
# Name: backbone.layer3.0.conv1.weight, Shape: torch.Size([256, 512, 1, 1])
# Name: backbone.layer3.0.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.0.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.0.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.0.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.0.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.0.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.0.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.0.downsample.0.weight, Shape: torch.Size([1024, 512, 1, 1])
# Name: backbone.layer3.0.downsample.1.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.0.downsample.1.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.1.conv1.weight, Shape: torch.Size([256, 1024, 1, 1])
# Name: backbone.layer3.1.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.1.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.1.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.1.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.1.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.1.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.1.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.2.conv1.weight, Shape: torch.Size([256, 1024, 1, 1])
# Name: backbone.layer3.2.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.2.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.2.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.2.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.2.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.2.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.2.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.2.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.3.conv1.weight, Shape: torch.Size([256, 1024, 1, 1])
# Name: backbone.layer3.3.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.3.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.3.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.3.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.3.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.3.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.3.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.3.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.4.conv1.weight, Shape: torch.Size([256, 1024, 1, 1])
# Name: backbone.layer3.4.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.4.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.4.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.4.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.4.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.4.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.4.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.4.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer3.5.conv1.weight, Shape: torch.Size([256, 1024, 1, 1])
# Name: backbone.layer3.5.bn1.weight, Shape: torch.Size([256])
# Name: backbone.layer3.5.bn1.bias, Shape: torch.Size([256])
# Name: backbone.layer3.5.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: backbone.layer3.5.bn2.weight, Shape: torch.Size([256])
# Name: backbone.layer3.5.bn2.bias, Shape: torch.Size([256])
# Name: backbone.layer3.5.conv3.weight, Shape: torch.Size([1024, 256, 1, 1])
# Name: backbone.layer3.5.bn3.weight, Shape: torch.Size([1024])
# Name: backbone.layer3.5.bn3.bias, Shape: torch.Size([1024])
# Name: backbone.layer4.0.conv1.weight, Shape: torch.Size([512, 1024, 1, 1])
# Name: backbone.layer4.0.bn1.weight, Shape: torch.Size([512])
# Name: backbone.layer4.0.bn1.bias, Shape: torch.Size([512])
# Name: backbone.layer4.0.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Name: backbone.layer4.0.bn2.weight, Shape: torch.Size([512])
# Name: backbone.layer4.0.bn2.bias, Shape: torch.Size([512])
# Name: backbone.layer4.0.conv3.weight, Shape: torch.Size([2048, 512, 1, 1])
# Name: backbone.layer4.0.bn3.weight, Shape: torch.Size([2048])
# Name: backbone.layer4.0.bn3.bias, Shape: torch.Size([2048])
# Name: backbone.layer4.0.downsample.0.weight, Shape: torch.Size([2048, 1024, 1, 1])
# Name: backbone.layer4.0.downsample.1.weight, Shape: torch.Size([2048])
# Name: backbone.layer4.0.downsample.1.bias, Shape: torch.Size([2048])
# Name: backbone.layer4.1.conv1.weight, Shape: torch.Size([512, 2048, 1, 1])
# Name: backbone.layer4.1.bn1.weight, Shape: torch.Size([512])
# Name: backbone.layer4.1.bn1.bias, Shape: torch.Size([512])
# Name: backbone.layer4.1.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Name: backbone.layer4.1.bn2.weight, Shape: torch.Size([512])
# Name: backbone.layer4.1.bn2.bias, Shape: torch.Size([512])
# Name: backbone.layer4.1.conv3.weight, Shape: torch.Size([2048, 512, 1, 1])
# Name: backbone.layer4.1.bn3.weight, Shape: torch.Size([2048])
# Name: backbone.layer4.1.bn3.bias, Shape: torch.Size([2048])
# Name: backbone.layer4.2.conv1.weight, Shape: torch.Size([512, 2048, 1, 1])
# Name: backbone.layer4.2.bn1.weight, Shape: torch.Size([512])
# Name: backbone.layer4.2.bn1.bias, Shape: torch.Size([512])
# Name: backbone.layer4.2.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Name: backbone.layer4.2.bn2.weight, Shape: torch.Size([512])
# Name: backbone.layer4.2.bn2.bias, Shape: torch.Size([512])
# Name: backbone.layer4.2.conv3.weight, Shape: torch.Size([2048, 512, 1, 1])
# Name: backbone.layer4.2.bn3.weight, Shape: torch.Size([2048])
# Name: backbone.layer4.2.bn3.bias, Shape: torch.Size([2048])
# Name: classifier.0.convs.0.0.weight, Shape: torch.Size([256, 2048, 1, 1])
# Name: classifier.0.convs.0.1.weight, Shape: torch.Size([256])
# Name: classifier.0.convs.0.1.bias, Shape: torch.Size([256])
# Name: classifier.0.convs.1.0.weight, Shape: torch.Size([256, 2048, 3, 3])
# Name: classifier.0.convs.1.1.weight, Shape: torch.Size([256])
# Name: classifier.0.convs.1.1.bias, Shape: torch.Size([256])
# Name: classifier.0.convs.2.0.weight, Shape: torch.Size([256, 2048, 3, 3])
# Name: classifier.0.convs.2.1.weight, Shape: torch.Size([256])
# Name: classifier.0.convs.2.1.bias, Shape: torch.Size([256])
# Name: classifier.0.convs.3.0.weight, Shape: torch.Size([256, 2048, 3, 3])
# Name: classifier.0.convs.3.1.weight, Shape: torch.Size([256])
# Name: classifier.0.convs.3.1.bias, Shape: torch.Size([256])
# Name: classifier.0.convs.4.1.weight, Shape: torch.Size([256, 2048, 1, 1])
# Name: classifier.0.convs.4.2.weight, Shape: torch.Size([256])
# Name: classifier.0.convs.4.2.bias, Shape: torch.Size([256])
# Name: classifier.0.project.0.weight, Shape: torch.Size([256, 1280, 1, 1])
# Name: classifier.0.project.1.weight, Shape: torch.Size([256])
# Name: classifier.0.project.1.bias, Shape: torch.Size([256])
# Name: classifier.1.weight, Shape: torch.Size([256, 256, 3, 3])
# Name: classifier.2.weight, Shape: torch.Size([256])
# Name: classifier.2.bias, Shape: torch.Size([256])
# Name: classifier.4.weight, Shape: torch.Size([21, 256, 1, 1])
# Name: classifier.4.bias, Shape: torch.Size([21])
# Name: aux_classifier.0.weight, Shape: torch.Size([256, 1024, 3, 3])
# Name: aux_classifier.1.weight, Shape: torch.Size([256])
# Name: aux_classifier.1.bias, Shape: torch.Size([256])
# Name: aux_classifier.4.weight, Shape: torch.Size([21, 256, 1, 1])
# Name: aux_classifier.4.bias, Shape: torch.Size([21])

# %%
import torch
from torch.quantization import fuse_modules

def get_fusible_module_patterns(model):
    fusible_patterns = []
    for name, module in model.named_modules():
        if isinstance(module, (torch.nn.Conv2d, torch.nn.Linear)):
            conv_bn_relu = []
            parent_name = name
            for child_name, child_module in module.named_children():
                full_child_name = parent_name + '.' + child_name if parent_name else child_name
                if isinstance(child_module, (torch.nn.BatchNorm2d, torch.nn.ReLU)):
                    conv_bn_relu.append(full_child_name)
                if len(conv_bn_relu) == 2 and isinstance(child_module, torch.nn.BatchNorm2d):
                    conv_bn_relu.append('relu')
                    fusible_patterns.append(conv_bn_relu)
                    break
                elif len(conv_bn_relu) == 1 and isinstance(child_module, torch.nn.ReLU):
                    conv_bn_relu.append(full_child_name)
                    fusible_patterns.append(conv_bn_relu)
                    break
    return fusible_patterns

# Example usage
# model = YourModel()
fusible_patterns = get_fusible_module_patterns(model)
print(fusible_patterns)
# Out:
# []

# %%
import torch
from torchvision.models.segmentation import deeplabv3_resnet50

# Load the pretrained DeepLab model
model = deeplabv3_resnet50(pretrained=True)

# %%
from torch.quantization import fuse_modules

def fuse_model(model):
    for module_name, module in model.named_children():
        if isinstance(module, torch.nn.Sequential):
            for idx in range(len(module)):
                if isinstance(module[idx], torch.nn.Conv2d) and idx + 2 < len(module):
                    if isinstance(module[idx + 1], torch.nn.BatchNorm2d) and isinstance(module[idx + 2], torch.nn.ReLU):
                        # Fuse Conv, BN, ReLU
                        fuse_modules(module, [str(idx), str(idx + 1), str(idx + 2)], inplace=True)
        else:
            fuse_model(module)  # Recursively fuse children layers

# Apply fusion to the model
fuse_model(model.backbone)

# %%
print(model)
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
def print_size_of_model(model):
    torch.save(model.state_dict(), "temp.p")
    print('Size (MB):', os.path.getsize("temp.p")/1e6)
    os.remove('temp.p')

# %%
print_size_of_model(model)
# Out:
# Size (MB): 168.351276

# %%
# !quota -vs
# Out:
# Disk quotas for user ksanka (uid 381380):
#      Filesystem   space   quota   limit   grace   files   quota   limit   grace
# 10.1.1.10:/home  32340M  39936M  40960M            299k       0       0

# %%
python3.8 train_classifier_ssfl.py --data_name CIFAR10 --model_name wresnet28x2 --control_name 1000_fix@0.85_5_0.3_non-iid-d-0.3_5-5_0.5_0_1
